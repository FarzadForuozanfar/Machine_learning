# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = np.mean(speed) 
y = np.median(speed)
w = np.var(speed)
q = np.std(speed)
x, y, w
#z = stats.mode(speed) #NameError: name 'stats' is not defined
# Out:
# (89.76923076923077, 87.0, 85.71597633136093)

# %%
#uniform var
x = np.random.uniform(1, 8, 100)

plt.hist(x, 10)
plt.show()

# %%
#normal var


x = np.random.normal(6, 2, 100)

plt.hist(x, 10)
plt.show()

# %%
x = np.random.normal(14, 2.5, 100)
y = np.random.normal(10, 20, 100)

plt.scatter(x, y, color = "red")
plt.show()

# %%
#Polynomial Regression

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22,23,24,25]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100,100,80,95]

mymodel = np.poly1d(np.polyfit(x, y,3))

myline = np.linspace(1, 25, 100)

plt.scatter(x, y, color = 'green')
plt.plot(myline, mymodel(myline), color = 'red')
plt.show()
